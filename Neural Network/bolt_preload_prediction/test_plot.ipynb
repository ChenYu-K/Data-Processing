# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
r1=np.linspace(0,200,200)
r2=np.linspace(0,200,200)
Real=[r1,r2]
predicted=[[185.2733, 178.1916, 2.7901, 31.4528, 71.882, 126.5616, 200.8528, 39.0987, 130.5821, 62.59, 156.7634, 65.0662, 159.0677],[188.0, 181.0, 2.0, 31.0, 73.0, 127.0, 202.0, 40.0, 131.0, 63.0, 158.0, 66.0, 161.0]]
print(predicted)
# Out:
# [[185.2733, 178.1916, 2.7901, 31.4528, 71.882, 126.5616, 200.8528, 39.0987, 130.5821, 62.59, 156.7634, 65.0662, 159.0677], [188.0, 181.0, 2.0, 31.0, 73.0, 127.0, 202.0, 40.0, 131.0, 63.0, 158.0, 66.0, 161.0]]

# %%
plt.xlabel("Predicted data")#x轴上的名字
plt.ylabel("True data")#y轴上的名字
plt.plot(Real[0],Real[1],label='True data')
plt.scatter(predicted[0],predicted[1],color='red',marker='*',label='predicted data')
plt.legend(loc=4)
plt.savefig('data.png',dpi=600)
