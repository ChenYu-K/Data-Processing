# %%
from glob import glob
from google.colab import drive
import csv
from collections import namedtuple
import numpy as np

###
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Colab_Notebooks/material_test'
filenames = glob('*.csv')
###

print(filenames)

#for filename in filenames:
with open('材料試験_H300W-No1_データリスト.csv',encoding="utf8",errors='ignore') as f:
  f_csv = csv.reader(f)
  next(f_csv)
  data = list(f_csv)
  a = np.array(data,dtype=object)
  x = range(np.shape(a)[0])
  y = len(data) - 1
  load 
  strantate1
  strantate2
  stranyoko1
  stranyoko2
################





###############

print(load)

#print(f_csv)
# Out:
#   File "<ipython-input-77-7c1849aedf7c>", line 23
#     load = a[*,2]
#              ^
# SyntaxError: invalid syntax
